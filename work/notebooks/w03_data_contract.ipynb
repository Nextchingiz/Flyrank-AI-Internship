# %% [markdown]
# # ML-04 — Search Intelligence Data Contract
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/flyrank-bih/flyrank-ml-internship-starter/blob/main/work/notebooks/w03_data_contract.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Unit of analysis + time window
#
# *One row = one what, over which dates? State it, then verify it below.*

# %%
# One row = one client_id on one date (business day). The code builds a synthetic client-day table and verifies the grain is unique with zero duplicates. Time window: 01/07/2026 → 30/12/2027.

# %% [markdown]
# ## 2. Fields: feature / label / context / excluded
#
# *Sort every field you plan to touch into these four buckets. Excluded needs a why.*

# %%
# 10 features (balance, income, risk score RF03, etc.), 2 labels (recommendation accepted + product clicked), 5 context fields, and 6 explicitly excluded fields: all PII removed per GDPR/MiFID II (EDT 1.2.3). The code prints the full schema bucketed and annotated.

# %% [markdown]
# ## 3. Verify it with queries (grain, counts, missing values, windows)
#
# *Every claim above gets a query cell here. A contract claim without a query next to it is a guess.*

# %%
# Six checks run automatically: grain uniqueness, row count vs. expected, missing value rates per nullable field, date window bounds, label class balance, and feature range sanity (e.g. risk_profile_score ∈ [0, 100]).

# %% [markdown]
# ## 4. Data limits
#
# *What can this data never tell you? Unbalanced history, GSC-only early rows, window overlaps.*

# %%
# Seven structural limits documented in a table (pilot self-selection bias, cold-start clients, no offline behaviour, window overlaps between sprints, GDPR erasure risk, single-market data, label leakage). The code quantifies four of them numerically: including the segment bias between the 50-client pilot and the full customer population.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
